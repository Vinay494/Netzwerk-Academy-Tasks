# %%
# Importing required libraries.
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
df=pd.read_csv("Covid-19 Twitter Dataset (Apr-Jun 2020).csv")

# %%
print(df.head())
# Out:
#              id                      created_at  \
# 0  1.250000e+18  Sun Apr 19 21:21:54 +0000 2020
# 1  1.250000e+18  Sun Apr 19 21:21:53 +0000 2020
# 2  1.250000e+18  Sun Apr 19 21:21:52 +0000 2020
# 3  1.250000e+18  Sun Apr 19 21:21:51 +0000 2020
# 4  1.250000e+18  Sun Apr 19 21:21:50 +0000 2020
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                        original_text lang  favorite_count  \
# 0  RT @GlblCtzn: .@priyankachopra is calling on l...   en             0.0
# 1  RT @OGSG_Official: OGUN STATE SUPPORT FOR CBN-...   en             0.0
# 2  RT @AdvoBarryRoux: These 5 police officials ba...   en             0.0
# 3  RT @MobilePunch: COVID-19: Oyo discharges two ...   en             0.0
# 4  My Condolences to the Family of those who did ...   en             0.0
#
#    retweet_count  original_author  hashtags             user_mentions  \
# 0           31.0          RJIshak       NaN  GlblCtzn, priyankachopra
# 1           61.0   makinwaoluwole       NaN             OGSG_Official
# 2            1.0         TembeAmu       NaN             AdvoBarryRoux
# 3            0.0       ilyasrabiu       NaN               MobilePunch
# 4        13869.0  bucketeconomist  Covid_19                       NaN
#
#                     place                                        clean_tweet  \
# 0  Jakarta Capital Region  call leader help protect refuge covid19 provid...
# 1                 Nigeria  ogun state support cbn nirsal covid19 target c...
# 2                     NaN  polic offici base namahadi polic station busi ...
# 3          Lagos, Nigeria                   covid19 oyo discharg two patient
# 4                     NaN                               condol famili surviv
#
#    compound  neg    neu    pos sentiment
# 0    0.8176  0.0  0.452  0.548       pos
# 1    0.6486  0.0  0.602  0.398       pos
# 2    0.2732  0.0  0.851  0.149       pos
# 3    0.0000  0.0  1.000  0.000       neu
# 4    0.0000  0.0  1.000  0.000       neu

# %%
print(df.dtypes)
# Out:
# id                 float64
# created_at          object
# source              object
# original_text       object
# lang                object
# favorite_count     float64
# retweet_count      float64
# original_author     object
# hashtags            object
# user_mentions       object
# place               object
# clean_tweet         object
# compound           float64
# neg                float64
# neu                float64
# pos                float64
# sentiment           object
# dtype: object

# %%
df.drop(["user_mentions"], axis=1)
# Out:
#                   id                      created_at  \
# 0       1.250000e+18  Sun Apr 19 21:21:54 +0000 2020
# 1       1.250000e+18  Sun Apr 19 21:21:53 +0000 2020
# 2       1.250000e+18  Sun Apr 19 21:21:52 +0000 2020
# 3       1.250000e+18  Sun Apr 19 21:21:51 +0000 2020
# 4       1.250000e+18  Sun Apr 19 21:21:50 +0000 2020
# ...              ...                             ...
# 235235  1.270000e+18  Sat Jun 20 20:44:31 +0000 2020
# 235236  1.270000e+18  Sat Jun 20 20:44:30 +0000 2020
# 235237  1.270000e+18  Sat Jun 20 20:44:29 +0000 2020
# 235238  1.270000e+18  Sat Jun 20 20:44:28 +0000 2020
# 235239  1.270000e+18  Sat Jun 20 20:44:27 +0000 2020
#
#                                                    source  \
# 0       <a href="http://twitter.com/download/android" ...
# 1       <a href="http://twitter.com/download/android" ...
# 2       <a href="http://twitter.com/download/iphone" r...
# 3       <a href="http://twitter.com/download/iphone" r...
# 4       <a href="http://twitter.com/download/android" ...
# ...                                                   ...
# 235235  <a href="http://twitter.com/download/android" ...
# 235236  <a href="https://mobile.twitter.com" rel="nofo...
# 235237  <a href="http://twitter.com/download/android" ...
# 235238  <a href="http://twitter.com/download/iphone" r...
# 235239  <a href="https://mobile.twitter.com" rel="nofo...
#
#                                             original_text lang  \
# 0       RT @GlblCtzn: .@priyankachopra is calling on l...   en
# 1       RT @OGSG_Official: OGUN STATE SUPPORT FOR CBN-...   en
# 2       RT @AdvoBarryRoux: These 5 police officials ba...   en
# 3       RT @MobilePunch: COVID-19: Oyo discharges two ...   en
# 4       My Condolences to the Family of those who did ...   en
# ...                                                   ...  ...
# 235235  RT @gemmaod1: Apologies for any fear or anxiet...   en
# 235236  Another meat processing outbreak - this time i...   en
# 235237  RT @HonorDecency: We knew Covid-19 would be sp...   en
# 235238  RT @EugeneDaniels2: President Trump is set to ...   en
# 235239  RT @DocJeffD: Friends, this story misses the m...   en
#
#         favorite_count  retweet_count  original_author  hashtags  \
# 0                  0.0           31.0          RJIshak       NaN
# 1                  0.0           61.0   makinwaoluwole       NaN
# 2                  0.0            1.0         TembeAmu       NaN
# 3                  0.0            0.0       ilyasrabiu       NaN
# 4                  0.0        13869.0  bucketeconomist  Covid_19
# ...                ...            ...              ...       ...
# 235235             0.0            1.0        twilouhom  Covid_19
# 235236             0.0          271.0         gmseed_T       NaN
# 235237             0.0            1.0   cinemaofdreams       NaN
# 235238             0.0         1971.0        murrell_h       NaN
# 235239             0.0         7476.0      BrodskyIgor       NaN
#
#                             place  \
# 0          Jakarta Capital Region
# 1                         Nigeria
# 2                             NaN
# 3                  Lagos, Nigeria
# 4                             NaN
# ...                           ...
# 235235            London, England
# 235236  United Kingdom of Torture
# 235237              AT THE MOVIES
# 235238                        NaN
# 235239           Philadelphia, PA
#
#                                               clean_tweet  compound    neg  \
# 0       call leader help protect refuge covid19 provid...    0.8176  0.000
# 1       ogun state support cbn nirsal covid19 target c...    0.6486  0.000
# 2       polic offici base namahadi polic station busi ...    0.2732  0.000
# 3                        covid19 oyo discharg two patient    0.0000  0.000
# 4                                    condol famili surviv    0.0000  0.000
# ...                                                   ...       ...    ...
# 235235  apolog fear anxieti caus claim surviv rate acq...   -0.4939  0.286
# 235236                 anoth meat process outbreak time u    0.0000  0.000
# 235237  knew covid19 would spread trump prais els rall...    0.5994  0.000
# 235238  presid trump set take half hour oklahoma ralli...    0.0000  0.000
# 235239  friend stori miss main point move forward open...    0.6705  0.086
#
#           neu    pos sentiment
# 0       0.452  0.548       pos
# 1       0.602  0.398       pos
# 2       0.851  0.149       pos
# 3       1.000  0.000       neu
# 4       1.000  0.000       neu
# ...       ...    ...       ...
# 235235  0.714  0.000       neg
# 235236  1.000  0.000       neu
# 235237  0.755  0.245       pos
# 235238  1.000  0.000       neu
# 235239  0.588  0.326       pos
#
# [235240 rows x 16 columns]
